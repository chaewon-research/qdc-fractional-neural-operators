# %% [markdown]
# # QDC QDC Fractional Neural Operators quickstart
# This notebook uses the same package and configurations as the workstation/HPC workflows. Full 64/128 and RealPDEBench runs are intentionally not launched by default because they are compute/data intensive.

# %%
# !pip install -q -r requirements.txt
# !pip install -q -e . --no-deps

# %%
# !python -m pytest -q

# %%
# !python experiments/run_smoke_scalar.py

# %% [markdown]
# ## Full central workflows
# Use `scripts/reproduce_core.sh`, `scripts/reproduce_qdc.sh`, and the matrix-free/RealPDEBench commands in the root README once the required runtime and data are available.
